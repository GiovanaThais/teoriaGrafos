# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovanaThais/teoriaGrafos/blob/main/arvoreGenerica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Grupo : Giovana Thais e Andrews da Mota**

# %% [markdown]
# # Arvore Generica

# %%
class TreeNode:
    def __init__(self, dados):
        self.dados = dados
        self.filhos = []
        self.pais = None

    def get_level(self):
        level = 0
        p = self.pais
        while p:
            level += 1
            p = p.pais
        return level

    def get_altura(self):
        ...
        
    def print_tree(self):
        grau = len(self.filhos)    
        profundidade = self.get_level()
        altura = self.get_altura()
        spaces = ' ' * self.get_level() * 3
        prefix = spaces + "|__" if self.pais else ""
        print(prefix + self.dados,(f'             Profundidade: {profundidade} nível: {profundidade}, Grau: {grau}  '))
        if self.filhos:
          for filhos in self.filhos:
                filhos.print_tree()
        
    def add_filhos(self, filhos):

        filhos.pais = self
        self.filhos.append(filhos)
   

def build_product_tree():
    root = TreeNode("Electronicos") #raiz 

    laptop = TreeNode("Laptop") #nó interno #subarvore 
    laptop.add_filhos(TreeNode("Mac"))#nó folha  
    laptop.add_filhos(TreeNode("Surface"))#nó folha 
    laptop.add_filhos(TreeNode("Thinkpad"))#nó folha 

    cellphone = TreeNode("Celular")#nó interno #subarvore 
    cellphone.add_filhos(TreeNode("iPhone")) #nó folha 
    cellphone.add_filhos(TreeNode("Google Pixel"))#nó folha 
    cellphone.add_filhos(TreeNode("Vivo"))#nó folha 

    tv = TreeNode("TV")#nó interno #subarvore 
    tv.add_filhos(TreeNode("Samsung"))#nó folha 
    tv.add_filhos(TreeNode("LG"))#nó folha 

    root.add_filhos(laptop)
    root.add_filhos(cellphone)
    root.add_filhos(tv)

    root.print_tree()
    print('''
    Altura de cada Nó:

     |_Eletronico: 2
          |_Laptop: 1
              |_Filhos: 0
          |_Celular: 1
              |_Filhos: 0
          |_Tv: 1
              |_Filhos: 0        ''')


build_product_tree()
# Out:
# Electronicos              Profundidade: 0 nível: 0, Grau: 3
#    |__Laptop              Profundidade: 1 nível: 1, Grau: 3
#       |__Mac              Profundidade: 2 nível: 2, Grau: 0
#       |__Surface              Profundidade: 2 nível: 2, Grau: 0
#       |__Thinkpad              Profundidade: 2 nível: 2, Grau: 0
#    |__Celular              Profundidade: 1 nível: 1, Grau: 3
#       |__iPhone              Profundidade: 2 nível: 2, Grau: 0
#       |__Google Pixel              Profundidade: 2 nível: 2, Grau: 0
#       |__Vivo              Profundidade: 2 nível: 2, Grau: 0
#    |__TV              Profundidade: 1 nível: 1, Grau: 2
#       |__Samsung              Profundidade: 2 nível: 2, Grau: 0
#       |__LG              Profundidade: 2 nível: 2, Grau: 0
#
#     Altura de cada Nó:
#
#      |_Eletronico: 2
#           |_Laptop: 1
#               |_Filhos: 0
#           |_Celular: 1
#               |_Filhos: 0
#           |_Tv: 1
#               |_Filhos: 0

# %% [markdown]
# # **Arvore Binaria**

# %%
'''
• Inserção OK
• Consulta OK
• Grau de um nó OK
• Profundidade de um nó OK
• Altura de um nó  Ok
• Níveis de um nó OK
• Uma função recursiva para retornar o número de nós de uma
árvore. Ok
• Remoção (Contemplando os três casos)
• Navegação (os três percursos vistos em sala com recursividade)
• Faça uma função que ao ler uma árvore e inverta as subárvores.
(imprima a árvore original e a nova ávore)
• Faça uma função que transforme uma árvore Binária em Binária de
Busca
'''




class BTree:
    def __init__(self, valor=None):
        self.valor = valor
        self.esq = None
        self.dir = None
        
    
    def inserir(self, valor):
        if self.valor:
            if valor <= self.valor:
                if self.esq is None:
                    self.esq = BTree(valor)
                else:
                    self.esq.inserir(valor)
            else:
                if self.dir is None:
                    self.dir = BTree(valor)
                else:
                    self.dir.inserir(valor)                           
        else:
            self.valor = valor

    def delete(self, node, valor):
            if node == None: 
               return None
            elif node.value == valor: 
               if node.esq is None and node.dir is None: 
               return None
            elif node.esq is None: 
                return node.esq
            elif node.dir is None: 
                return node.dir 
            else: 
                node.value = get_min(node.right)
                node.right.delete(node.right,node.value)
            elif k < node.value: 
                node.left.delete(node.left,k)
            else: 
                node.right.delete(node.right,k)
            return node

             
    def buscar(self, valor):
        if valor < self.valor:
            if self.esq is None:
                return str(valor) + " Não encontrado"
            return self.esq.buscar(valor)
        
        elif valor > self.valor:
            if self.dir is None:
                return str(valor) + " Não encontrado"
            return self.dir.buscar(valor)
        
        else:
            return self.valor
                    
    def profundidade(self, valor, cont = 1):   
        if valor < self.valor:
            if self.esq is None:
                return str(valor) + " Não encontrado"
            cont+=1
            return self.esq.profundidade(valor, cont)
        
        elif valor > self.valor:
            if self.dir is None:
                return str(valor) + " Não encontrado"
            cont+=1
            return self.dir.profundidade(valor, cont)     
        else:
            return(f'Profundidade do nó {valor} é {cont}') 

    def grau(self,valor): 
        if valor < self.valor:
            if self.esq is None:
                return str(valor) + " Não encontrado"
            return self.esq.grau(valor)
        
        elif valor > self.valor:
            if self.dir is None:
                return str(valor) + " Não encontrado"
            return self.dir.grau(valor)
        else:
            if  self.esq is not None and self.dir is not None:
                return(f'Grau do Nó {valor} é 2')
            elif self.esq is not None or self.dir is not None:
                return(f'Grau do Nó {valor} é 1')
            else:
                return(f'Grau do Nó {valor} é 0')

    def altura(self):
        altura_esq = 0
        altura_dir = 0
        if self is None:
            return 0
        else:
            altura_esq+=1
            altura_dir+=1
            if self.dir != None:
                altura_dir += self.dir.altura()  
            if self.esq != None:
                altura_esq += self.esq.altura()
        if altura_esq > altura_dir:
            return altura_esq
                     
        return (altura_dir)
                    
    def alturaNo(self, valor):
        if valor < self.valor:
            if self.esq is None:
                return str(valor) + " Não encontrado"
            return self.esq.alturaNo(valor)
        
        elif valor > self.valor:
            if self.dir is None:
                return str(valor) + " Não encontrado"
            return self.dir.alturaNo(valor)
        
        else:
            return (BTree.altura(self))
             
    def alturaTotal(self):
        altura = 0
        if self is None:
            return 0
        else:
            altura+=1
            if self.dir != None:
                altura += self.dir.altura()  
            if self.esq != None:
                altura += self.esq.altura()
        return (altura)
                 
    def display(self):
        lines, *_ = self._display_aux()
        for line in lines:
            print(line)

    def _display_aux(self):

        if self.dir is None and self.esq is None:
            line = '%s' % self.valor
            width = len(line)
            height = 1
            middle = width // 2
            return [line], width, height, middle


        if self.dir is None:
            lines, n, p, x = self.esq._display_aux()
            s = '%s' % self.valor
            u = len(s)
            first_line = (x + 1) * ' ' + (n - x - 1) * ' ' + s
            second_line = x * ' ' + '/' + (n - x - 1 + u) * ' '
            shifted_lines = [line + u * ' ' for line in lines]
            return [first_line, second_line] + shifted_lines, n + u, p + 2, n + u // 2


        if self.esq is None:
            lines, n, p, x = self.dir._display_aux()
            s = '%s' % self.valor
            u = len(s)
            first_line = s + x * ' ' + (n - x) * ' '
            second_line = (u + x) * ' ' + '\\' + (n - x - 1) * ' '
            shifted_lines = [u * ' ' + line for line in lines]
            return [first_line, second_line] + shifted_lines, n + u, p + 2, u // 2

        esq, n, p, x = self.esq._display_aux()
        dir, m, q, y = self.dir._display_aux()
        s = '%s' % self.valor
        u = len(s)
        first_line = (x + 1) * ' ' + (n - x - 1) * '_' + s + y * '_' + (m - y) * ' '
        second_line = x * ' ' + '/' + (n - x - 1 + u + y) * ' ' + '\\' + (m - y - 1) * ' '
        if p < q:
            esq += [n * ' '] * (q - p)
        elif q < p:
            dir += [m * ' '] * (p - q)
        zipped_lines = zip(esq, dir)
        lines = [first_line, second_line] + [a + u * ' ' + b for a, b in zipped_lines]
        return lines, n + m + u, max(p, q) + 2, n + u // 2     
            
            
                
root = BTree(12)

root.inserir(10)
root.inserir(9)    
root.inserir(15)
root.inserir(2)
root.inserir(11)
root.inserir(14)

#root.altura(1)
print(root.profundidade(10))
print(f'Altura do Nó: {root.alturaNo(2)}')
print(f'Altura da Arvore: {root.alturaTotal()}')
print(root.grau(12))
#print(root.buscar(15))
root.display()
# Out:
# Profundidade do nó 10 é 2
# Altura do Nó: 1
# Altura da Arvore: 6
# Grau do Nó 12 é 2
#     __12___
#    /       \
#   10_     15
#  /   \   /
#  9  11  14
# /
# 2
